# %% [raw]
# I have no rights to this images, it is just an exercise I did on Python Bootcamp and it is cute!

# %%
import PIL
from PIL import Image

# %%
puzzle = Image.open("word_matrix.png")

# %%
(x_p, y_p)=puzzle.size
print(x_p)
print(y_p)
# Out:
# 1015
# 559

# %%
mask = Image.open("mask.png")

# %%
(x_m, y_m) = mask.size

# %%
mask.size
# Out:
# (505, 251)

# %%
new_mask = mask.resize((x_p, y_p))
new_mask.putalpha(120)
new_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x24DD2E1E1F0>

# %%
puzzle.paste(im= new_mask, box=(0,0),mask = new_mask)

# %%
puzzle
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x24DD1D79E50>
